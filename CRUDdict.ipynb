# %%
student = {}

student["name"] = input("Enter student name: ")
student["marks"] = int(input("Enter student marks: "))

print("Student Dictionary:", student)
# Out:
# Enter student name:  Vikky
# Enter student marks:  95
# Student Dictionary: {'name': 'Vikky', 'marks': 95}

# %%
fruits = {
    "Apple": 120,
    "Banana": 40,
    "Mango": 80,
    "Orange": 60,
    "Grapes": 90
}

print("Fruit Prices Dictionary:", fruits)
# Out:
# Fruit Prices Dictionary: {'Apple': 120, 'Banana': 40, 'Mango': 80, 'Orange': 60, 'Grapes': 90}

# %%
fruits = {
    "Apple": 120,
    "Banana": 40,
    "Mango": 80,
    "Orange": 60,
    "Grapes": 90
}

print("Fruit Prices Dictionary:", fruits)
# Out:
# Fruit Prices Dictionary: {'Apple': 120, 'Banana': 40, 'Mango': 80, 'Orange': 60, 'Grapes': 90}

# %%
employees = {
    "Raj": 30000,
    "Priya": 45000,
    "Arjun": 50000,
    "Nehan": 40000
}

name = input("Enter employee name: ")

if name in employees:
    print("Salary of", name, "is", employees[name])
else:
    print("Employee not found")
# Out:
# Enter employee name:  Raj
# Salary of Raj is 30000

# %%
countries = {
    "India": "New Delhi",
    "USA": "Washington, D.C.",
    "Japan": "Tokyo",
    "France": "Paris",
    "Australia": "Canberra"
}

print("Countries and their Capitals:")

for country, capital in countries.items():
    print(country, ":", capital)
# Out:
# Countries and their Capitals:
# India : New Delhi
# USA : Washington, D.C.
# Japan : Tokyo
# France : Paris
# Australia : Canberra

# %%
students = {
    "Raj": 85,
    "Priya": 90,
    "Arjun": 78
}

name = input("Enter student name: ")
new_marks = int(input("Enter new marks: "))

if name in students:
    students[name] = new_marks
    print("Updated Dictionary:", students)
else:
    print("Student not found")
# Out:
# Enter student name:  Rani
# Enter new marks:  85
# Student not found

# %%
inventory = {
    "Pen": 50,
    "Notebook": 30,
    "Pencil": 100
}

product = input("Enter product name: ")
amount = int(input("Enter quantity to add: "))

if product in inventory:
    inventory[product] += amount
    print("Updated Inventory:", inventory)
else:
    print("Product not found")
# Out:
# Enter product name:  Pen
# Enter quantity to add:  50
# Updated Inventory: {'Pen': 100, 'Notebook': 30, 'Pencil': 100}

# %%
students = {
    "Ravi": 85,
    "Priya": 90,
    "Arjun": 78
}

key = input("Enter the key to delete: ")

if key in students:
    del students[key]
    print("Updated Dictionary:", students)
else:
    print("Key not found")
# Out:
# Enter the key to delete:  3
# Key not found

# %%
students = {
    "Ravi": 85,
    "Priya": 90,
    "Arjun": 78
}

key = input("Enter the key to delete: ")

if key in students:
    del students[key]
    print("Updated Dictionary:", students)
else:
    print("Key not found")
# Out:
# Enter the key to delete:  Priya
# Updated Dictionary: {'Ravi': 85, 'Arjun': 78}

# %%
fruits = {
    "Apple": 125,
    "Banana": 450,
    "Mango": 90,
    "Orange": 60,
    "Grapes": 100
}

fruits.clear()

print("Dictionary after removing all items:", fruits)
# Out:
# Dictionary after removing all items: {}
